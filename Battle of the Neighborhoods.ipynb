# %% [markdown]
# __Battle of Neighborhoods - Part 1__
#
# __1. A description of the problem and a discussion of the background__
#
# This project's aim is to define the best area to work out between Playa Vista, CA, Marina del Rey, CA and Playa del Rey, CA. I intend to analysis the number of gyms and yoga studio.
#
# __2.A description of the data and how it will be used to solve the problem__
#
# I am planning on using FourSquare to aggregate data and focus on the number of options to work out.
#
# ***
#
# __Battle of Neighborhoods - Part 2__
#
# __3. Introduction where you discuss the business problem and who would be interested in this project.__
#
# Which city is best to visit to work out? This problem is useful for future resident or for work out afficionados.
#
# __4. Data where you describe the data that will be used to solve the problem and the source of the data.__
#
# Data aggregated from FourSquare
#
# __5. Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.__
#
# Use of Histograms, Maps, and pandas
#
# __6. Results section where you discuss the results.__
#
# According to the data, the best city to work out between those three is Marina del Rey, CA.
#
# __7. Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.__
#
# Marina del Rey, CA has the most palces to work out, but Los Angeles has more places to work out overall.
#
# __8. Conclusion section where you conclude the report.__
#
# In conclusion, Marina del Rey, CA has the most palces to work out, but Los Angeles has more places to work out overall.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.19.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  23.69 MB/s
# geopy-1.19.0-p 100% |################################| Time: 0:00:00  36.52 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  50.41 MB/s
# ...

# %%
# Log in FourSquare

CLIENT_ID = 'W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q' # your Foursquare ID
CLIENT_SECRET = 'LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q
# CLIENT_SECRET:LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW

# %%
address = 'Playa del Rey, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.9550828 -118.4367496

# %% [markdown]
# __1. Search for yoga studios in a 5000 radius around Playa del Rey, CA__

# %%
search_query = 'Yoga'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Yoga .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q&client_secret=LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW&ll=33.9550828,-118.4367496&v=20180604&query=Yoga&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb0b50edd579740b127137c'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4e23a7947d8b71715bc1d493',
#     'location': {'address': '38 Washington Blvd',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'crossStreet': 'Pacific',
#      'distance': 3809,
#      'formattedAddress': ['38 Washington Blvd (Pacific)',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.97957780500059,
#        'lng': -118.46557130972641}],
#      'lat': 33.97957780500059,
#      'lng': -118.46557130972641,
#      'postalCode': '90292',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Yoga Studio', 'name': 'Yoga St...    False
# 1  [{'shortName': 'Yoga Studio', 'name': 'Yoga St...    False
# 2  [{'shortName': 'Yoga Studio', 'name': 'Yoga St...    False
# 3  [{'shortName': 'Yoga Studio', 'name': 'Yoga St...    False
# 4  [{'shortName': 'Yoga Studio', 'name': 'Yoga St...    False
#
#                          id            location.address location.cc  \
# 0  4e23a7947d8b71715bc1d493          38 Washington Blvd          US
# 1  4b098c52f964a520371923e3                512 Rose Ave          US
# 2  59d8fe5f018cbb2116b0663b           2570 Lincoln Blvd          US
# 3  4c41e315da3dc928b68fc9b9  13020 Pacific Promenade #3          US
# 4  5b5faf995455b2002cfb9afb         12105 Waterfront Dr          US
#
#     location.city location.country location.crossStreet  location.distance  \
# 0  Marina del Rey    United States              Pacific               3809
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered_yoga = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_yoga['categories'] = dataframe_filtered_yoga.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered_yoga.columns = [column.split('.')[-1] for column in dataframe_filtered_yoga.columns]

dataframe_filtered_yoga
# Out:
#                                                name            categories  \
# 0                                  Yoga Nest Venice           Yoga Studio
# 1                               The Yoga Collective           Yoga Studio
# 2                                    Modo Yoga West           Yoga Studio
# 3                                        Yoga Vista           Yoga Studio
# 4                                        Sweat Yoga           Yoga Studio
# 5                      Bikram Yoga Instructor Class                School
# 6                                         Love Yoga           Yoga Studio
# 7                                        Power Yoga           Yoga Studio
# 8                             Mind Body & Soul Yoga           Yoga Studio
# 9                             Yoga Sutras With Atma           Yoga Studio
# 10                                 Yoga Nest Venice           Yoga Studio
# 11                                        Yoga Salt           Yoga Studio
# ...

# %%
# Let's visualize the Yoga Studios  that are nearby
dataframe_filtered_yoga.name
# Out:
# 0                                    Yoga Nest Venice
# 1                                 The Yoga Collective
# 2                                      Modo Yoga West
# 3                                          Yoga Vista
# 4                                          Sweat Yoga
# 5                        Bikram Yoga Instructor Class
# 6                                           Love Yoga
# 7                                          Power Yoga
# 8                               Mind Body & Soul Yoga
# 9                               Yoga Sutras With Atma
# 10                                   Yoga Nest Venice
# 11                                          Yoga Salt
# 12                              YogaWorks Playa Vista
# 13                                          Yoga Salt
# 14                                  Studio Surya Yoga
# 15                         Bikram Yoga Marina Del Rey
# 16                                          Yoga Rays
# ...

# %%
#Count how many yoga studio there is next to Playa del Rey, CA
df_yoga = dataframe_filtered_yoga['city'].value_counts()
df_yoga
# Out:
# Los Angeles       13
# Marina del Rey     8
# Venice             4
# Culver City        2
# Ladera Heights     1
# El Segundo         1
# Playa Vista        1
# Name: city, dtype: int64

# %%
# generate map of yoga studios centered around Playa del Rey

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 
# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# __2. Search for gym studios in a 5000 radius around Playa del Rey, CA__

# %%
search_query = 'Gym'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Gym .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q&client_secret=LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW&ll=33.9550828,-118.4367496&v=20180604&query=Gym&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb0b38cf594df78c4415a9b'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4bcf6fdfb221c9b69207d2d0',
#     'location': {'address': '13700 Tahiti Way',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'crossStreet': 'at Via Marina',
#      'distance': 2399,
#      'formattedAddress': ['13700 Tahiti Way (at Via Marina)',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.973666485704065,
#        'lng': -118.4499205593676}],
#      'lat': 33.973666485704065,
#      'lng': -118.4499205593676,
#      'postalCode': '90292',
#      'state': 'CA'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Gym', 'name': 'Gym', 'id': '4b...    False
# 1  [{'shortName': 'Gym', 'name': 'Gym', 'id': '4b...    False
# 2  [{'shortName': 'Gym', 'name': 'Gym', 'id': '4b...    False
# 3  [{'shortName': 'Gym', 'name': 'Gym', 'id': '4b...    False
# 4  [{'shortName': 'Gym', 'name': 'Gym', 'id': '4b...    False
#
#                          id          location.address location.cc  \
# 0  4bcf6fdfb221c9b69207d2d0          13700 Tahiti Way          US
# 1  4b5e390cf964a520a48429e3  6000 Sepulveda Boulevard          US
# 2  51919ca0498e147bcf41b5f7          4133 Redwood Ave          US
# 3  4cbd027b4c60a093cab654ca       2240 E Imperial Hwy          US
# 4  4bd64f7bcfa7b713cf7e27da       9400 LA Tijera Blvd          US
#
#     location.city location.country location.crossStreet  location.distance  \
# 0  Marina del Rey    United States        at Via Marina               2399
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered_gym = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_gym['categories'] = dataframe_filtered_gym.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered_gym.columns = [column.split('.')[-1] for column in dataframe_filtered_gym.columns]

dataframe_filtered_gym
# Out:
#                                                  name  \
# 0                                 Gym @ Tahiti Marina
# 1                                          Gold's Gym
# 2                                         The Fix Gym
# 3                                   The Gym | DIRECTV
# 4                             Park West Apartment Gym
# 5   BeachSide Norterra Community Center, Pools, Pa...
# 6                           Easton Gym Mahattan Beach
# 7                                 Malibu - Villas Gym
# 8                                             The Gym
# 9                         The Gym At Mariners Village
# 10                                  Marina Harbor Gym
# 11                                           Aqua gym
# 12                                 Gym @ The Breakers
# 13                                          Brisa Gym
# 14                                           The Gym!
# 15                               Gym @ Casa De Marina
# ...

# %%
#Count how many gym studio there is next to Playa del Rey, CA
df_gym = dataframe_filtered_gym['city'].value_counts()
df_gym
# Out:
# Los Angeles        16
# Playa del Rey       5
# Marina del Rey      5
# Culver City         1
# El Segundo          1
# Venice              1
# Manhattan Beach     1
# Name: city, dtype: int64

# %%
# Los Angeles = 15 + 13 = 28
# Playa del Rey = 0 + 5 = 5
# Marina del Rey = 8 + 5 = 13
# Playa Vista = 1 + 0 = 1

# %% [markdown]
# to be continued...
