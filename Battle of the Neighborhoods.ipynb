# %% [markdown]
# __Battle of Neighborhoods - Part 1__
#
# __1. A description of the problem and a discussion of the background__
#
# This project's aim is to define the best area to work out between Playa Vista, CA, and Playa del Rey, CA. I intend to analysis the number of gyms, yoga studio and parks.
#
# __2.A description of the data and how it will be used to solve the problem__
#
# I am planning on using FourSquare to aggregate data and focus on the number of options to work out.
#
# ***
#
# __Battle of Neighborhoods - Part 2__
#
# __3. Introduction where you discuss the business problem and who would be interested in this project.__
#
# Which city is best to visit to work out? This problem is useful for future resident or for work out afficionados.
#
# __4. Data where you describe the data that will be used to solve the problem and the source of the data.__
#
# Data aggregated from FourSquare
#
# __5. Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.__
#
# Use of Histograms, Maps, and pd.values_count
#
# __6. Results section where you discuss the results.__
#
# According to the data, the best city to work out is Playa Vista, CA
#
# __7. Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.__
#
# Playa Vista has a significant number of places to work out, but Playa del Rey has more natural parks and has the beach.
#
# __8. Conclusion section where you conclude the report.__
#
# In conclusion, the best city to work out is Playa Vista, CA.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.19.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed
# Libraries imported.

# %%
# Log in FourSquare

CLIENT_ID = 'W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q' # your Foursquare ID
CLIENT_SECRET = 'LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q
# CLIENT_SECRET:LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW

# %%
address = 'Playa del Rey, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.9550828 -118.4367496

# %% [markdown]
# __1. Search for yoga studios in a 5000 radius around Playa del Rey, CA__

# %%
search_query = 'Yoga'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Yoga .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W2QHU2K2ZV0TYRS1LZN1XRNPZROAAP3VILHKFOIDS5EYD03Q&client_secret=LIKTZQJNCJKPPSPSGTU4HRZ3G151UI2ENHYHZMYJQBCVAYIW&ll=33.9550828,-118.4367496&v=20180604&query=Yoga&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cae5e41db04f540302bab21'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4e23a7947d8b71715bc1d493',
#     'location': {'address': '38 Washington Blvd',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'crossStreet': 'Pacific',
#      'distance': 3809,
#      'formattedAddress': ['38 Washington Blvd (Pacific)',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.97957780500059,
#        'lng': -118.46557130972641}],
#      'lat': 33.97957780500059,
#      'lng': -118.46557130972641,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Yoga Nest Venice',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4b098c52f964a520371923e3',
#     'location': {'address': '512 Rose Ave',
#      'cc': 'US',
#      'city': 'Venice',
#      'country': 'United States',
#      'distance': 5890,
#      'formattedAddress': ['512 Rose Ave', 'Venice, CA 90291', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.99833887718099,
#        'lng': -118.47350253746806}],
#      'lat': 33.99833887718099,
#      'lng': -118.47350253746806,
#      'postalCode': '90291',
#      'state': 'CA'},
#     'name': 'The Yoga Collective',
#     'referralId': 'v-1554931265',
#     'venuePage': {'id': '124580038'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '59d8fe5f018cbb2116b0663b',
#     'location': {'address': '2570 Lincoln Blvd',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 4073,
#      'formattedAddress': ['2570 Lincoln Blvd',
#       'Los Angeles, CA 90291',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.99050565439297,
#        'lng': -118.44780236817934}],
#      'lat': 33.99050565439297,
#      'lng': -118.44780236817934,
#      'postalCode': '90291',
#      'state': 'CA'},
#     'name': 'Modo Yoga West',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'primary': True,
#       'shortName': 'School'}],
#     'hasPerk': False,
#     'id': '525c2f9711d2a459e5e946e4',
#     'location': {'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 4010,
#      'formattedAddress': ['Los Angeles, CA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.945749,
#        'lng': -118.394798}],
#      'lat': 33.945749,
#      'lng': -118.394798,
#      'state': 'CA'},
#     'name': 'Bikram Yoga Instructor Class',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '5b5faf995455b2002cfb9afb',
#     'location': {'address': '12105 Waterfront Dr',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 4083,
#      'formattedAddress': ['12105 Waterfront Dr',
#       'Los Angeles, CA 90094',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.981695,
#        'lng': -118.406314}],
#      'lat': 33.981695,
#      'lng': -118.406314,
#      'postalCode': '90094',
#      'state': 'CA'},
#     'name': 'Sweat Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4c41e315da3dc928b68fc9b9',
#     'location': {'address': '13020 Pacific Promenade #3',
#      'cc': 'US',
#      'city': 'Playa Vista',
#      'country': 'United States',
#      'distance': 2325,
#      'formattedAddress': ['13020 Pacific Promenade #3',
#       'Playa Vista, CA 90094',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9727897778422,
#        'lng': -118.42338375889207}],
#      'lat': 33.9727897778422,
#      'lng': -118.42338375889207,
#      'neighborhood': 'West Los Angeles',
#      'postalCode': '90094',
#      'state': 'CA'},
#     'name': 'Yoga Vista',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '561fb0c1498eb927ef08677d',
#     'location': {'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 5422,
#      'formattedAddress': ['Los Angeles, CA 90291', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9986186814696,
#        'lng': -118.4630936879463}],
#      'lat': 33.9986186814696,
#      'lng': -118.4630936879463,
#      'postalCode': '90291',
#      'state': 'CA'},
#     'name': 'Love Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '5178b1f6e4b079827c3f6622',
#     'location': {'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 1558,
#      'formattedAddress': ['Los Angeles, CA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.962762,
#        'lng': -118.45086}],
#      'lat': 33.962762,
#      'lng': -118.45086,
#      'state': 'CA'},
#     'name': 'Power Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '5ac82b0116fa0438cdfd79b1',
#     'location': {'address': '13020 Pacific Promenade',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 2333,
#      'formattedAddress': ['13020 Pacific Promenade',
#       'Los Angeles, CA 90094',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.972866,
#        'lng': -118.423373}],
#      'lat': 33.972866,
#      'lng': -118.423373,
#      'postalCode': '90094',
#      'state': 'CA'},
#     'name': 'Mind Body & Soul Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4f4c4f7be4b051dc47321f3a',
#     'location': {'address': '13900 Marquesas Way, Marina Del Rey, CA 90292',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'distance': 2745,
#      'formattedAddress': ['13900 Marquesas Way, Marina Del Rey, CA 90292',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.976417541503906,
#        'lng': -118.45166015625}],
#      'lat': 33.976417541503906,
#      'lng': -118.45166015625,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Yoga Sutras With Atma',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '50ecc48ff13622f3074c547b',
#     'location': {'address': '38 Washington Blvd',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'distance': 3818,
#      'formattedAddress': ['38 Washington Blvd',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.979586310386196,
#        'lng': -118.46569418907164}],
#      'lat': 33.979586310386196,
#      'lng': -118.46569418907164,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Yoga Nest Venice',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '552c6f08498e8589de03d5f6',
#     'location': {'address': '12746 W. Jefferson Blvd, Suite 3120',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 3117,
#      'formattedAddress': ['12746 W. Jefferson Blvd, Suite 3120',
#       'Los Angeles, CA 90094',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.977501,
#        'lng': -118.41651}],
#      'lat': 33.977501,
#      'lng': -118.41651,
#      'postalCode': '90094',
#      'state': 'CA'},
#     'name': 'YogaWorks Playa Vista',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4ba82b5bf964a52022cf39e3',
#     'location': {'address': '1501 Main St #106',
#      'cc': 'US',
#      'city': 'Venice',
#      'country': 'United States',
#      'crossStreet': 'at Market St',
#      'distance': 4933,
#      'formattedAddress': ['1501 Main St #106 (at Market St)',
#       'Venice, CA 90291',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.988550310861164,
#        'lng': -118.47177704547731}],
#      'lat': 33.988550310861164,
#      'lng': -118.47177704547731,
#      'postalCode': '90291',
#      'state': 'CA'},
#     'name': 'Studio Surya Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4b9aa69af964a520cac935e3',
#     'location': {'address': '13325 Beach Ave',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'distance': 4169,
#      'formattedAddress': ['13325 Beach Ave',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.992245,
#        'lng': -118.442405}],
#      'lat': 33.992245,
#      'lng': -118.442405,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Sivananda Yoga Center',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4c1eb5e6b4e62d7f7ab8de93',
#     'location': {'address': '3007 Wasgington Blvd.',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'distance': 3980,
#      'formattedAddress': ['3007 Wasgington Blvd.',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.989075,
#        'lng': -118.45012664794922}],
#      'lat': 33.989075,
#      'lng': -118.45012664794922,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Yoga Rays',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '55fc5fb7498e2c019f638363',
#     'location': {'address': '11955 Washington Blvd',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 4983,
#      'formattedAddress': ['11955 Washington Blvd',
#       'Los Angeles, CA 90066',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9980174,
#        'lng': -118.4214657}],
#      'lat': 33.9980174,
#      'lng': -118.4214657,
#      'postalCode': '90066',
#      'state': 'CA'},
#     'name': 'Yoga Salt',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '564a8bf8498e6ad173df9f6c',
#     'location': {'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 3958,
#      'formattedAddress': ['Los Angeles, CA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.95968003617379,
#        'lng': -118.39423972808969}],
#      'lat': 33.95968003617379,
#      'lng': -118.39423972808969,
#      'state': 'CA'},
#     'name': 'Yoga Bliss',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'primary': True,
#       'shortName': 'Athletics & Sports'}],
#     'hasPerk': False,
#     'id': '52e6891a11d259538d2f754e',
#     'location': {'address': '4745 Slauson Avenue',
#      'cc': 'US',
#      'city': 'Ladera Heights',
#      'country': 'United States',
#      'distance': 7046,
#      'formattedAddress': ['4745 Slauson Avenue',
#       'Ladera Heights, CA 90056',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.988224610994855,
#        'lng': -118.37172031402588}],
#      'lat': 33.988224610994855,
#      'lng': -118.37172031402588,
#      'postalCode': '90056',
#      'state': 'CA'},
#     'name': 'Yoga Metrics',
#     'referralId': 'v-1554931265',
#     'venuePage': {'id': '77289591'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '5324fd5c498e455c65ef80a6',
#     'location': {'address': '4206 Lincoln Blvd',
#      'cc': 'US',
#      'city': 'Culver City',
#      'country': 'United States',
#      'distance': 3598,
#      'formattedAddress': ['4206 Lincoln Blvd',
#       'Culver City, CA 90066',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.98681803663123,
#        'lng': -118.44413977083065}],
#      'lat': 33.98681803663123,
#      'lng': -118.44413977083065,
#      'postalCode': '90066',
#      'state': 'CA'},
#     'name': 'Yoga Salt',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'primary': True,
#       'shortName': 'Garden'}],
#     'hasPerk': False,
#     'id': '4e2afd26ae605c533a32a7eb',
#     'location': {'address': 'Westminister',
#      'cc': 'US',
#      'city': 'Venice',
#      'country': 'United States',
#      'distance': 4914,
#      'formattedAddress': ['Westminister', 'Venice, CA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.99159067,
#        'lng': -118.46668745}],
#      'lat': 33.99159067,
#      'lng': -118.46668745,
#      'state': 'CA'},
#     'name': 'Yoga In The Garden',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '568b0a61498e50936875be95',
#     'location': {'address': '11831 Courtleigh Dr',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 5056,
#      'formattedAddress': ['11831 Courtleigh Dr',
#       'Los Angeles, CA 90066',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.997951,
#        'lng': -118.41865}],
#      'lat': 33.997951,
#      'lng': -118.41865,
#      'postalCode': '90066',
#      'state': 'CA'},
#     'name': 'Yoga With Aria',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '5c1a88754b78c5002c1739c3',
#     'location': {'address': '4371 Glencoe Ave',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'distance': 3279,
#      'formattedAddress': ['4371 Glencoe Ave',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9844623,
#        'lng': -118.4394002}],
#      'lat': 33.9844623,
#      'lng': -118.4394002,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'CorePower Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4b5e390cf964a520a48429e3',
#     'location': {'address': '6000 Sepulveda Boulevard',
#      'cc': 'US',
#      'city': 'Culver City',
#      'country': 'United States',
#      'distance': 5054,
#      'formattedAddress': ['6000 Sepulveda Boulevard',
#       'Culver City, CA 90230',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9845779,
#        'lng': -118.395124}],
#      'lat': 33.9845779,
#      'lng': -118.395124,
#      'postalCode': '90230',
#      'state': 'CA'},
#     'name': "Gold's Gym",
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '50aa9e744b90af0d42d5de0e',
#       'name': 'Health Food Store',
#       'pluralName': 'Health Food Stores',
#       'primary': True,
#       'shortName': 'Health Food Store'}],
#     'hasPerk': False,
#     'id': '53c3736f498e6f68176607c3',
#     'location': {'address': '411 Brooks Ave',
#      'cc': 'US',
#      'city': 'Venice',
#      'country': 'United States',
#      'distance': 5389,
#      'formattedAddress': ['411 Brooks Ave',
#       'Venice, CA 90291',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.99567899879598,
#        'lng': -118.46855878829957}],
#      'lat': 33.99567899879598,
#      'lng': -118.46855878829957,
#      'postalCode': '90291',
#      'state': 'CA'},
#     'name': 'Yoga Retreats on Seek Retreat',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'primary': True,
#       'shortName': 'Spa'}],
#     'hasPerk': False,
#     'id': '4e289062ae60078b2fcca222',
#     'location': {'address': '3401 Pacific Ave Ste 2A',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'crossStreet': 'Driftwood',
#      'distance': 3611,
#      'formattedAddress': ['3401 Pacific Ave Ste 2A (Driftwood)',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.97783470000002,
#        'lng': -118.46463187486876}],
#      'lat': 33.97783470000002,
#      'lng': -118.46463187486876,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Creative Chakra Spa & Yoga',
#     'referralId': 'v-1554931265',
#     'venuePage': {'id': '57985035'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '51390947e4b0515b353df51b',
#     'location': {'address': '13031 W Jefferson Blvd',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'crossStreet': 'Alla Rd.',
#      'distance': 5686,
#      'formattedAddress': ['13031 W Jefferson Blvd (Alla Rd.)',
#       'Los Angeles, CA 90094',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.918896181350135,
#        'lng': -118.39328665765726}],
#      'lat': 33.918896181350135,
#      'lng': -118.39328665765726,
#      'postalCode': '90094',
#      'state': 'CA'},
#     'name': 'Team One Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '4f9575ae00396d202f32597f',
#     'location': {'address': '2903 Washington Blvd',
#      'cc': 'US',
#      'city': 'Marina del Rey',
#      'country': 'United States',
#      'crossStreet': 'Abbot Kinney & Washington',
#      'distance': 3957,
#      'formattedAddress': ['2903 Washington Blvd (Abbot Kinney & Washington)',
#       'Marina del Rey, CA 90292',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.98840500015554,
#        'lng': -118.45169254181202}],
#      'lat': 33.98840500015554,
#      'lng': -118.45169254181202,
#      'postalCode': '90292',
#      'state': 'CA'},
#     'name': 'Bikram Yoga Marina Del Rey',
#     'referralId': 'v-1554931265',
#     'venuePage': {'id': '42915769'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4b0187e7f964a520284322e3',
#     'location': {'address': '6225 W Century Blvd',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 3992,
#      'formattedAddress': ['6225 W Century Blvd',
#       'Los Angeles, CA 90045',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.9459893519267,
#        'lng': -118.39492494350485}],
#      'lat': 33.9459893519267,
#      'lng': -118.39492494350485,
#      'postalCode': '90045',
#      'state': 'CA'},
#     'name': 'Hyatt Regency Los Angeles International Airport',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'primary': True,
#       'shortName': 'Yoga Studio'}],
#     'hasPerk': False,
#     'id': '59b2d45e588e364f7e8891b3',
#     'location': {'address': 'S Sepulveda Blvd & La Tijera B',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'country': 'United States',
#      'distance': 3704,
#      'formattedAddress': ['S Sepulveda Blvd & La Tijera B',
#       'Los Angeles, CA 90045',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.957695,
#        'lng': -118.39675}],
#      'lat': 33.957695,
#      'lng': -118.39675,
#      'postalCode': '90045',
#      'state': 'CA'},
#     'name': 'Body & Brain Yoga',
#     'referralId': 'v-1554931265'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'primary': True,
#       'shortName': 'Gym / Fitness'}],
#     'hasPerk': False,
#     'id': '587f959124ca6a664986f898',
#     'location': {'cc': 'US',
#      'city': 'El Segundo',
#      'country': 'United States',
#      'distance': 4650,
#      'formattedAddress': ['El Segundo, CA 90245', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.92834,
#        'lng': -118.398056}],
#      'lat': 33.92834,
#      'lng': -118.398056,
#      'postalCode': '90245',
#      'state': 'CA'},
#     'name': 'CTI Yoga',
#     'referralId': 'v-1554931265'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Yoga Studio', 'pluralName': 'Yoga S...    False
# 1  [{'name': 'Yoga Studio', 'pluralName': 'Yoga S...    False
# 2  [{'name': 'Yoga Studio', 'pluralName': 'Yoga S...    False
# 3  [{'name': 'School', 'pluralName': 'Schools', '...    False
# 4  [{'name': 'Yoga Studio', 'pluralName': 'Yoga S...    False
#
#                          id     location.address location.cc   location.city  \
# 0  4e23a7947d8b71715bc1d493   38 Washington Blvd          US  Marina del Rey
# 1  4b098c52f964a520371923e3         512 Rose Ave          US          Venice
# 2  59d8fe5f018cbb2116b0663b    2570 Lincoln Blvd          US     Los Angeles
# 3  525c2f9711d2a459e5e946e4                  NaN          US     Los Angeles
# 4  5b5faf995455b2002cfb9afb  12105 Waterfront Dr          US     Los Angeles
#
#   location.country location.crossStreet  location.distance  \
# 0    United States              Pacific               3809
# 1    United States                  NaN               5890
# 2    United States                  NaN               4073
# 3    United States                  NaN               4010
# 4    United States                  NaN               4083
#
#                            location.formattedAddress  \
# 0  [38 Washington Blvd (Pacific), Marina del Rey,...
# 1    [512 Rose Ave, Venice, CA 90291, United States]
# 2  [2570 Lincoln Blvd, Los Angeles, CA 90291, Uni...
# 3                   [Los Angeles, CA, United States]
# 4  [12105 Waterfront Dr, Los Angeles, CA 90094, U...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lng': -118.46557130972641, 'label': 'displa...     33.979578
# 1  [{'lng': -118.47350253746806, 'label': 'displa...     33.998339
# 2  [{'lng': -118.44780236817934, 'label': 'displa...     33.990506
# 3  [{'lng': -118.394798, 'label': 'display', 'lat...     33.945749
# 4  [{'lng': -118.406314, 'label': 'display', 'lat...     33.981695
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0   -118.465571                   NaN               90292             CA
# 1   -118.473503                   NaN               90291             CA
# 2   -118.447802                   NaN               90291             CA
# 3   -118.394798                   NaN                 NaN             CA
# 4   -118.406314                   NaN               90094             CA
#
#                            name    referralId venuePage.id
# 0              Yoga Nest Venice  v-1554931265          NaN
# 1           The Yoga Collective  v-1554931265    124580038
# 2                Modo Yoga West  v-1554931265          NaN
# 3  Bikram Yoga Instructor Class  v-1554931265          NaN
# 4                    Sweat Yoga  v-1554931265          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name            categories  \
# 0                                  Yoga Nest Venice           Yoga Studio
# 1                               The Yoga Collective           Yoga Studio
# 2                                    Modo Yoga West           Yoga Studio
# 3                      Bikram Yoga Instructor Class                School
# 4                                        Sweat Yoga           Yoga Studio
# 5                                        Yoga Vista           Yoga Studio
# 6                                         Love Yoga           Yoga Studio
# 7                                        Power Yoga           Yoga Studio
# 8                             Mind Body & Soul Yoga           Yoga Studio
# 9                             Yoga Sutras With Atma           Yoga Studio
# 10                                 Yoga Nest Venice           Yoga Studio
# 11                            YogaWorks Playa Vista           Yoga Studio
# 12                                Studio Surya Yoga           Yoga Studio
# 13                            Sivananda Yoga Center                  None
# 14                                        Yoga Rays           Yoga Studio
# 15                                        Yoga Salt           Yoga Studio
# 16                                       Yoga Bliss           Yoga Studio
# 17                                     Yoga Metrics    Athletics & Sports
# 18                                        Yoga Salt           Yoga Studio
# 19                               Yoga In The Garden                Garden
# 20                                   Yoga With Aria           Yoga Studio
# 21                                   CorePower Yoga           Yoga Studio
# 22                                       Gold's Gym                   Gym
# 23                    Yoga Retreats on Seek Retreat     Health Food Store
# 24                       Creative Chakra Spa & Yoga                   Spa
# 25                                    Team One Yoga           Yoga Studio
# 26                       Bikram Yoga Marina Del Rey           Yoga Studio
# 27  Hyatt Regency Los Angeles International Airport                 Hotel
# 28                                Body & Brain Yoga           Yoga Studio
# 29                                         CTI Yoga  Gym / Fitness Center
#
#                                           address  cc            city  \
# 0                              38 Washington Blvd  US  Marina del Rey
# 1                                    512 Rose Ave  US          Venice
# 2                               2570 Lincoln Blvd  US     Los Angeles
# 3                                             NaN  US     Los Angeles
# 4                             12105 Waterfront Dr  US     Los Angeles
# 5                      13020 Pacific Promenade #3  US     Playa Vista
# 6                                             NaN  US     Los Angeles
# 7                                             NaN  US     Los Angeles
# 8                         13020 Pacific Promenade  US     Los Angeles
# 9   13900 Marquesas Way, Marina Del Rey, CA 90292  US  Marina del Rey
# 10                             38 Washington Blvd  US  Marina del Rey
# 11            12746 W. Jefferson Blvd, Suite 3120  US     Los Angeles
# 12                              1501 Main St #106  US          Venice
# 13                                13325 Beach Ave  US  Marina del Rey
# 14                          3007 Wasgington Blvd.  US  Marina del Rey
# 15                          11955 Washington Blvd  US     Los Angeles
# 16                                            NaN  US     Los Angeles
# 17                            4745 Slauson Avenue  US  Ladera Heights
# 18                              4206 Lincoln Blvd  US     Culver City
# 19                                   Westminister  US          Venice
# 20                            11831 Courtleigh Dr  US     Los Angeles
# 21                               4371 Glencoe Ave  US  Marina del Rey
# 22                       6000 Sepulveda Boulevard  US     Culver City
# 23                                 411 Brooks Ave  US          Venice
# 24                        3401 Pacific Ave Ste 2A  US  Marina del Rey
# 25                         13031 W Jefferson Blvd  US     Los Angeles
# 26                           2903 Washington Blvd  US  Marina del Rey
# 27                            6225 W Century Blvd  US     Los Angeles
# 28                 S Sepulveda Blvd & La Tijera B  US     Los Angeles
# 29                                            NaN  US      El Segundo
#
#           country                crossStreet  distance  \
# 0   United States                    Pacific      3809
# 1   United States                        NaN      5890
# 2   United States                        NaN      4073
# 3   United States                        NaN      4010
# 4   United States                        NaN      4083
# 5   United States                        NaN      2325
# 6   United States                        NaN      5422
# 7   United States                        NaN      1558
# 8   United States                        NaN      2333
# 9   United States                        NaN      2745
# 10  United States                        NaN      3818
# 11  United States                        NaN      3117
# 12  United States               at Market St      4933
# 13  United States                        NaN      4169
# 14  United States                        NaN      3980
# 15  United States                        NaN      4983
# 16  United States                        NaN      3958
# 17  United States                        NaN      7046
# 18  United States                        NaN      3598
# 19  United States                        NaN      4914
# 20  United States                        NaN      5056
# 21  United States                        NaN      3279
# 22  United States                        NaN      5054
# 23  United States                        NaN      5389
# 24  United States                  Driftwood      3611
# 25  United States                   Alla Rd.      5686
# 26  United States  Abbot Kinney & Washington      3957
# 27  United States                        NaN      3992
# 28  United States                        NaN      3704
# 29  United States                        NaN      4650
#
#                                      formattedAddress  \
# 0   [38 Washington Blvd (Pacific), Marina del Rey,...
# 1     [512 Rose Ave, Venice, CA 90291, United States]
# 2   [2570 Lincoln Blvd, Los Angeles, CA 90291, Uni...
# 3                    [Los Angeles, CA, United States]
# 4   [12105 Waterfront Dr, Los Angeles, CA 90094, U...
# 5   [13020 Pacific Promenade #3, Playa Vista, CA 9...
# 6              [Los Angeles, CA 90291, United States]
# 7                    [Los Angeles, CA, United States]
# 8   [13020 Pacific Promenade, Los Angeles, CA 9009...
# 9   [13900 Marquesas Way, Marina Del Rey, CA 90292...
# 10  [38 Washington Blvd, Marina del Rey, CA 90292,...
# 11  [12746 W. Jefferson Blvd, Suite 3120, Los Ange...
# 12  [1501 Main St #106 (at Market St), Venice, CA ...
# 13  [13325 Beach Ave, Marina del Rey, CA 90292, Un...
# 14  [3007 Wasgington Blvd., Marina del Rey, CA 902...
# 15  [11955 Washington Blvd, Los Angeles, CA 90066,...
# 16                   [Los Angeles, CA, United States]
# 17  [4745 Slauson Avenue, Ladera Heights, CA 90056...
# 18  [4206 Lincoln Blvd, Culver City, CA 90066, Uni...
# 19          [Westminister, Venice, CA, United States]
# 20  [11831 Courtleigh Dr, Los Angeles, CA 90066, U...
# 21  [4371 Glencoe Ave, Marina del Rey, CA 90292, U...
# 22  [6000 Sepulveda Boulevard, Culver City, CA 902...
# 23  [411 Brooks Ave, Venice, CA 90291, United States]
# 24  [3401 Pacific Ave Ste 2A (Driftwood), Marina d...
# 25  [13031 W Jefferson Blvd (Alla Rd.), Los Angele...
# 26  [2903 Washington Blvd (Abbot Kinney & Washingt...
# 27  [6225 W Century Blvd, Los Angeles, CA 90045, U...
# 28  [S Sepulveda Blvd & La Tijera B, Los Angeles, ...
# 29              [El Segundo, CA 90245, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lng': -118.46557130972641, 'label': 'displa...  33.979578 -118.465571
# 1   [{'lng': -118.47350253746806, 'label': 'displa...  33.998339 -118.473503
# 2   [{'lng': -118.44780236817934, 'label': 'displa...  33.990506 -118.447802
# 3   [{'lng': -118.394798, 'label': 'display', 'lat...  33.945749 -118.394798
# 4   [{'lng': -118.406314, 'label': 'display', 'lat...  33.981695 -118.406314
# 5   [{'lng': -118.42338375889207, 'label': 'displa...  33.972790 -118.423384
# 6   [{'lng': -118.4630936879463, 'label': 'display...  33.998619 -118.463094
# 7   [{'lng': -118.45086, 'label': 'display', 'lat'...  33.962762 -118.450860
# 8   [{'lng': -118.423373, 'label': 'display', 'lat...  33.972866 -118.423373
# 9   [{'lng': -118.45166015625, 'label': 'display',...  33.976418 -118.451660
# 10  [{'lng': -118.46569418907164, 'label': 'displa...  33.979586 -118.465694
# 11  [{'lng': -118.41651, 'label': 'display', 'lat'...  33.977501 -118.416510
# 12  [{'lng': -118.47177704547731, 'label': 'displa...  33.988550 -118.471777
# 13  [{'lng': -118.442405, 'label': 'display', 'lat...  33.992245 -118.442405
# 14  [{'lng': -118.45012664794922, 'label': 'displa...  33.989075 -118.450127
# 15  [{'lng': -118.4214657, 'label': 'display', 'la...  33.998017 -118.421466
# 16  [{'lng': -118.39423972808969, 'label': 'displa...  33.959680 -118.394240
# 17  [{'lng': -118.37172031402588, 'label': 'displa...  33.988225 -118.371720
# 18  [{'lng': -118.44413977083065, 'label': 'displa...  33.986818 -118.444140
# 19  [{'lng': -118.46668745, 'label': 'display', 'l...  33.991591 -118.466687
# 20  [{'lng': -118.41865, 'label': 'display', 'lat'...  33.997951 -118.418650
# 21  [{'lng': -118.4394002, 'label': 'display', 'la...  33.984462 -118.439400
# 22  [{'lng': -118.395124, 'label': 'display', 'lat...  33.984578 -118.395124
# 23  [{'lng': -118.46855878829957, 'label': 'displa...  33.995679 -118.468559
# 24  [{'lng': -118.46463187486876, 'label': 'displa...  33.977835 -118.464632
# 25  [{'lng': -118.39328665765726, 'label': 'displa...  33.918896 -118.393287
# 26  [{'lng': -118.45169254181202, 'label': 'displa...  33.988405 -118.451693
# 27  [{'lng': -118.39492494350485, 'label': 'displa...  33.945989 -118.394925
# 28  [{'lng': -118.39675, 'label': 'display', 'lat'...  33.957695 -118.396750
# 29  [{'lng': -118.398056, 'label': 'display', 'lat...  33.928340 -118.398056
#
#         neighborhood postalCode state                        id
# 0                NaN      90292    CA  4e23a7947d8b71715bc1d493
# 1                NaN      90291    CA  4b098c52f964a520371923e3
# 2                NaN      90291    CA  59d8fe5f018cbb2116b0663b
# 3                NaN        NaN    CA  525c2f9711d2a459e5e946e4
# 4                NaN      90094    CA  5b5faf995455b2002cfb9afb
# 5   West Los Angeles      90094    CA  4c41e315da3dc928b68fc9b9
# 6                NaN      90291    CA  561fb0c1498eb927ef08677d
# 7                NaN        NaN    CA  5178b1f6e4b079827c3f6622
# 8                NaN      90094    CA  5ac82b0116fa0438cdfd79b1
# 9                NaN      90292    CA  4f4c4f7be4b051dc47321f3a
# 10               NaN      90292    CA  50ecc48ff13622f3074c547b
# 11               NaN      90094    CA  552c6f08498e8589de03d5f6
# 12               NaN      90291    CA  4ba82b5bf964a52022cf39e3
# 13               NaN      90292    CA  4b9aa69af964a520cac935e3
# 14               NaN      90292    CA  4c1eb5e6b4e62d7f7ab8de93
# 15               NaN      90066    CA  55fc5fb7498e2c019f638363
# 16               NaN        NaN    CA  564a8bf8498e6ad173df9f6c
# 17               NaN      90056    CA  52e6891a11d259538d2f754e
# 18               NaN      90066    CA  5324fd5c498e455c65ef80a6
# 19               NaN        NaN    CA  4e2afd26ae605c533a32a7eb
# 20               NaN      90066    CA  568b0a61498e50936875be95
# 21               NaN      90292    CA  5c1a88754b78c5002c1739c3
# 22               NaN      90230    CA  4b5e390cf964a520a48429e3
# 23               NaN      90291    CA  53c3736f498e6f68176607c3
# 24               NaN      90292    CA  4e289062ae60078b2fcca222
# 25               NaN      90094    CA  51390947e4b0515b353df51b
# 26               NaN      90292    CA  4f9575ae00396d202f32597f
# 27               NaN      90045    CA  4b0187e7f964a520284322e3
# 28               NaN      90045    CA  59b2d45e588e364f7e8891b3
# 29               NaN      90245    CA  587f959124ca6a664986f898

# %%
# Let's visualize the Italian restaurants that are nearby
dataframe_filtered.city
# Out:
# 0     Marina del Rey
# 1             Venice
# 2        Los Angeles
# 3        Los Angeles
# 4        Los Angeles
# 5        Playa Vista
# 6        Los Angeles
# 7        Los Angeles
# 8        Los Angeles
# 9     Marina del Rey
# 10    Marina del Rey
# 11       Los Angeles
# 12            Venice
# 13    Marina del Rey
# 14    Marina del Rey
# 15       Los Angeles
# 16       Los Angeles
# 17    Ladera Heights
# 18       Culver City
# 19            Venice
# 20       Los Angeles
# 21    Marina del Rey
# 22       Culver City
# 23            Venice
# 24    Marina del Rey
# 25       Los Angeles
# 26    Marina del Rey
# 27       Los Angeles
# 28       Los Angeles
# 29        El Segundo
# Name: city, dtype: object

# %%
#Count how many yoga studio there is next to Playa del Rey, CA
dataframe_filtered['city'].value_counts()
# Out:
# Los Angeles       13
# Marina del Rey     8
# Venice             4
# Culver City        2
# Ladera Heights     1
# Playa Vista        1
# El Segundo         1
# Name: city, dtype: int64

# %%
# generate map of yoga studios centered around Playa del Rey

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 
# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
